# %% [markdown]
# ***Write a program that asks the user for their name and age,then print sasentence like***

# %%
name=input("enter your name")
age=input("enter your age")
print(f"Hello {name}, you are {age} year old!" )
# Out:
# enter your nameAditya
# enter your age21
# Hello Aditya, you are 21 year old!

# %% [markdown]
# ***Take two numbers as input from the user and print their sum,difference,product,and quotient***

# %%
num1=int(input("enter first num"))
num2=int(input("enter second num"))
print("Sum of two number:",num1+num2)
print("difference of two number:",num1-num2)
print("product of two number:",num1*num2)
print("division of two number:",num1/num2)
print("modulo of two numbers:",num1%num2)
# Out:
# enter first num10
# enter second num20
# Sum of two number: 30
# difference of two number: -10
# product of two number: 200
# division of two number: 0.5
# modulo of two numbers: 10

# %% [markdown]
# ***Ask the user to enter two integers and one float.Convert them all to floats and print their average***

# %%
num1=int(input("enter first num"))
num2=int(input("enter second numb"))
num3=float(input("enter third num"))
print(float(num1))
print(float(num2))
print(float(num3))
print("average of three numbers:",(num1+num2+num3)/3)
# Out:
# enter first num12
# enter second numb15
# enter third num18
# 12.0
# 15.0
# 18.0
# average of three numbers: 15.0

# %% [markdown]
# The user enters a string containing a number(e.g.,"45").convert it to:
# . an integer
# . a float
# . a string again
# print all three values with their types

# %%
text=input("enter a string containing number:")
int_value=int(text)
float_value=float(text)
str_value=str(text)
print(int_value,type(int_value))
print(float_value,type(float_value))
print(str_value,type(str_value))
# Out:
# enter a string containing number:45
# 45 <class 'int'>
# 45.0 <class 'float'>
# 45 <class 'str'>

# %% [markdown]
# Q5. evaluate and print the result of the following expression:
# x=10+3*2**2

# %%
x=10+3*2**2
print(x)
# Out:
# 22

# %% [markdown]
# ***Write a program to swap values of two numbers entered by the user***

# %%
#easy method using a temporary variable
a=int(input("enter first number:"))
b=int(input("enter second number:"))
temp=a
a=b
b=temp
print(a,b)

#without temperoray variable,addition and substraction
a=int(input("enter first number:"))
b=int(input("enter second number:"))
a=a+b
b=a-b
a=a-b
print(a,b)

#using multiplication and division
a=int(input("enter first number:"))
b=int(input("enter second number:"))
a=a*b
b=a//b
a=a//b
print(a,b)
# Out:
# enter first number:5
# enter second number:10
# 10 5
# enter first number:3
# enter second number:2
# 2 3
# enter first number:4
# enter second number:5
# 5 4

# %%
a=50
b=8
print(a//b)
# Out:
# 6

# %% [markdown]
# **Ask the user to temperature in celsius(string input). convert it to float,than calculate and print the temperature in farenheit**

# %%
temperature=input("enter temperature in celsius:")
temperature=float(temperature)
farenheit=(temperature*(9/5))+32
print("faremheit is:",farenheit)
# Out:
# enter temperature in celsius:24
# faremheit is: 75.2

# %% [markdown]
# ***Q8. take the radious(r) as user input and print the area***

# %%
r=int(input("enter the radius"))
Area=3.14*r*r
print("Area of radius is:",Area)
# Out:
# enter the radius5
# Area of radius is: 78.5

# %% [markdown]
# ***Q9. Ask the user for:principle(p),rate(r),time(t),. convert all to float and compute simple interest***

# %%
principle=int(input("enter the principle:"))
rate=int(input("enter the rate:"))
time=int(input("enter the time:"))
principle=float(principle)
rate=float(rate)
time=float(time)
si=(principle*rate*time)/100
print("simple interest is:",si)
# Out:
# enter the principle:50000
# enter the rate:4
# enter the time:3
# simple interest is: 6000.0

# %% [markdown]
# Q10.take a decimal number as input(like 45.68) and output is:
# ->integer part=45
# ->decimal par= .68

# %%
num=float(input("enter a decimal number:"))
integer_part=int(num)
fractional_part=num-integer_part
print("integer part:",integer_part)
print("fractional part:",fractional_part)
# Out:
# enter a decimal number:45.68
# integer part: 45
# fractional part: 0.6799999999999997
